# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
from sklearn.cluster import KMeans

# %%
raw_data=pd.read_csv('C:\\Users\\KIIT\\Downloads\\Countries-exercise.csv')
raw_data
# Out:
#              name   Longitude   Latitude
# 0           Aruba  -69.982677  12.520880
# 1     Afghanistan   66.004734  33.835231
# 2          Angola   17.537368 -12.293361
# 3        Anguilla  -63.064989  18.223959
# 4         Albania   20.049834  41.142450
# ..            ...         ...        ...
# 236         Samoa -172.164851 -13.753243
# 237         Yemen   47.586762  15.909280
# 238  South Africa   25.083901 -29.000341
# 239        Zambia   27.774759 -13.458242
# 240      Zimbabwe   29.851441 -19.004204
#
# [241 rows x 3 columns]

# %%
data=raw_data.copy()
data
# Out:
#              name   Longitude   Latitude
# 0           Aruba  -69.982677  12.520880
# 1     Afghanistan   66.004734  33.835231
# 2          Angola   17.537368 -12.293361
# 3        Anguilla  -63.064989  18.223959
# 4         Albania   20.049834  41.142450
# ..            ...         ...        ...
# 236         Samoa -172.164851 -13.753243
# 237         Yemen   47.586762  15.909280
# 238  South Africa   25.083901 -29.000341
# 239        Zambia   27.774759 -13.458242
# 240      Zimbabwe   29.851441 -19.004204
#
# [241 rows x 3 columns]

# %%
plt.scatter(data['Longitude'],data['Latitude'])
plt.xlabel('Longitude',fontsize=20)
plt.ylabel('Latitude',fontsize=20)
plt.show()

# %%
x=data.iloc[:,1:3]
x
# Out:
#       Longitude   Latitude
# 0    -69.982677  12.520880
# 1     66.004734  33.835231
# 2     17.537368 -12.293361
# 3    -63.064989  18.223959
# 4     20.049834  41.142450
# ..          ...        ...
# 236 -172.164851 -13.753243
# 237   47.586762  15.909280
# 238   25.083901 -29.000341
# 239   27.774759 -13.458242
# 240   29.851441 -19.004204
#
# [241 rows x 2 columns]

# %%
n_init_value = 10
kmeans = KMeans(n_clusters=5,n_init=n_init_value)

# %%
kmeans.fit(x)
# Out:
# KMeans(n_clusters=5, n_init=10)

# %%
identified_clusters = kmeans.fit_predict(x)
identified_clusters
# Out:
# array([3, 4, 4, 3, 1, 1, 1, 4, 3, 1, 2, 4, 0, 4, 3, 0, 1, 1, 4, 1, 1, 1,
#        0, 1, 4, 3, 3, 1, 3, 1, 3, 3, 3, 3, 3, 0, 0, 4, 4, 1, 3, 0, 1, 4,
#        4, 4, 2, 3, 4, 1, 3, 3, 3, 3, 1, 1, 1, 1, 4, 3, 1, 3, 1, 3, 1, 4,
#        1, 1, 4, 1, 0, 3, 1, 1, 0, 4, 1, 1, 1, 1, 1, 1, 1, 4, 1, 3, 1, 3,
#        0, 3, 0, 4, 3, 1, 3, 1, 0, 1, 4, 0, 4, 1, 4, 4, 1, 1, 1, 3, 1, 1,
#        0, 4, 4, 4, 4, 0, 3, 3, 0, 1, 4, 0, 1, 1, 1, 3, 1, 4, 4, 1, 1, 1,
#        0, 3, 1, 1, 1, 4, 4, 3, 0, 1, 1, 1, 0, 1, 0, 0, 4, 1, 3, 4, 4, 0,
#        4, 0, 1, 0, 1, 3, 2, 1, 1, 0, 0, 0, 4, 4, 3, 2, 3, 0, 0, 0, 1, 3,
#        0, 1, 3, 1, 2, 4, 1, 0, 4, 1, 4, 4, 4, 1, 0, 3, 4, 0, 1, 3, 1, 4,
#        4, 3, 1, 4, 3, 1, 1, 1, 4, 3, 4, 1, 3, 1, 1, 0, 4, 4, 0, 2, 3, 1,
#        1, 0, 4, 4, 1, 3, 3, 4, 1, 3, 3, 3, 3, 0, 0, 2, 2, 4, 4, 4, 4])

# %%
data_with_clusters = data.copy()
data_with_clusters['Cluster'] = identified_clusters
data_with_clusters
# Out:
#              name   Longitude   Latitude  Cluster
# 0           Aruba  -69.982677  12.520880        3
# 1     Afghanistan   66.004734  33.835231        4
# 2          Angola   17.537368 -12.293361        4
# 3        Anguilla  -63.064989  18.223959        3
# 4         Albania   20.049834  41.142450        1
# ..            ...         ...        ...      ...
# 236         Samoa -172.164851 -13.753243        2
# 237         Yemen   47.586762  15.909280        4
# 238  South Africa   25.083901 -29.000341        4
# 239        Zambia   27.774759 -13.458242        4
# 240      Zimbabwe   29.851441 -19.004204        4
#
# [241 rows x 4 columns]

# %%
plt.scatter(data['Longitude'], data['Latitude'],c=data_with_clusters['Cluster'], cmap = 'rainbow')
plt.xlim(-180,180)
plt.ylim(-90, 90)
plt.show()
